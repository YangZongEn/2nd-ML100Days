# %% [markdown]
# # 作業
# ### 用 digits (3個數字即可 , dataset.load_digits(n_class=3)) 資料嘗試跑 PCA

# %%
from sklearn import datasets

digits = datasets.load_digits(n_class=3)
X = digits.data
y = digits.target

# %% [markdown]
# 載入 相關套件 並 執行 PCA 實驗 ...

# %%
import numpy as np
import matplotlib.pyplot as plt
from mpl_toolkits.mplot3d import Axes3D

from sklearn import decomposition

np.random.seed(5)
# %matplotlib inline

pca = decomposition.PCA(n_components=3)

# %%
pca.fit(X)
pca_X = pca.transform(X)

# %%
fig = plt.figure(1, figsize=(4, 3))
plt.clf()
ax = Axes3D(fig, rect=[0, 0, .95, 1], elev=48, azim=134)
plt.cla()

for name, label in [('0', 0), ('1', 1), ('2', 2)]:
    print(X[y == label, 0].mean() + 10, X[y == label, 1].mean() + 30, X[y == label, 2].mean())
    ax.text3D(X[y == label, 0].mean() +10,
              X[y == label, 1].mean() + 30,
              X[y == label, 2].mean(), name,
              horizontalalignment='center',
              bbox=dict(alpha=.5, edgecolor='w', facecolor='w'))

# y = np.choose(y, [1, 2, 0]).astype(np.float)
ax.scatter(pca_X[:, 0], pca_X[:, 1], pca_X[:, 2], c=y, cmap=plt.cm.nipy_spectral, edgecolor='k')

# ax.w_xaxis.set_ticklabels([])
# ax.w_yaxis.set_ticklabels([])
# ax.w_zaxis.set_ticklabels([])

plt.show()
# Out:
# 10.0 30.02247191011236 4.185393258426966
# 10.0 30.01098901098901 2.456043956043956
# 10.0 30.93220338983051 9.666666666666666
